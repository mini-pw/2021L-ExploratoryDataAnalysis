# %%
import pandas as pd

# %% [markdown]
# ## Pakiet `pandas_profiling`

# %%
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('data/forestfires.csv')
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
profile = ProfileReport(df, title="Fores Fires dataset")

# %%
profile.to_file("forestfires-pandas.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Pakiet `dtale`

# %%
import dtale

# %%
boston_dict = load_boston()
df = pd.DataFrame(boston_dict['data'], columns=boston_dict['feature_names'])
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
d = dtale.show(df)
d.open_browser()

# %% [markdown]
# ## Pakiet `sweetviz`

# %%
import sweetviz

# %%
df = pd.read_csv('data/heart.csv')
df
# Out:
#      sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  age  \
# 0    160    12.00   5.73      23.11  Present     49    25.30    97.20   52
# 1    144     0.01   4.41      28.61   Absent     55    28.87     2.06   63
# 2    118     0.08   3.48      32.28  Present     52    29.14     3.81   46
# 3    170     7.50   6.41      38.03  Present     51    31.99    24.26   58
# 4    134    13.60   3.50      27.78  Present     60    25.99    57.34   49
# ..   ...      ...    ...        ...      ...    ...      ...      ...  ...
# 457  214     0.40   5.98      31.72   Absent     64    28.45     0.00   58
# 458  182     4.20   4.41      32.10   Absent     52    28.61    18.72   52
# 459  108     3.00   1.59      15.23   Absent     40    20.09    26.64   55
# 460  118     5.40  11.61      30.79   Absent     64    27.35    23.97   40
# 461  132     0.00   4.82      33.41  Present     62    14.70     0.00   46
#
#      chd
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
# ...

# %%
my_report  = sweetviz.analyze([df,'Train'], target_feat='chd')
my_report.show_html('FinalReport.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report FinalReport.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
my_report  = sweetviz.compare([df[:300],'Train'], [df[300:],'Test'], target_feat='chd')
my_report.show_html('FinalReport.html')

# %% [markdown]
# ## Pakiet `autoviz`

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.

# %%
AV = AutoViz_Class()
df = AV.AutoViz('data/menshoes.csv', depVar='prices_amountmin')
# Out:
# Shape of your Data Set: (18280, 48)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  15
#     Number of NLP String Columns =  10
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  17
#     47 Predictors classified...
#         This does not include the Target column(s)
#         42 variables removed since they were ID or low-information variables
#
# ################ Regression VISUALIZATION Started #####################
# Number of All Scatter Plots = 6
# All Plots done
# Time to run AutoViz (in seconds) = 10.770
#
# ...

# %%
AV.AutoViz?

# %% [markdown]
# ## Podsumowanie

# %% [markdown]
# Jakie są zalety narzędzi do automatycznej EDA?
# - ?

# %% [markdown]
# Jakie są wady?
# - ?
